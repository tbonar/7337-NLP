# %% [markdown]
# # HW5
# ## MSDS-7337
# ## Author: Taylor Bonar
# ---

# %%
from platform import python_version
import bs4
import pandas as pd
import requests
import re
import nltk

print(f"""Python Version: {python_version()}
NLTK v.{nltk.__version__}
BeautifulSoup v.{bs4.__version__}
Pandas v.{pd.__version__}
Requests v.{requests.__version__}
Re v. {re.__version__}""")
# Out:
# Python Version: 3.8.12
# NLTK v.3.6.5
# BeautifulSoup v.4.9.3
# Pandas v.1.1.3
# Requests v.2.26.0
# Re v. 2.2.1

# %% [markdown]
# 1.	Compile a list of static links (permalinks) to individual user movie reviews from one particular website. This will be your working dataset for this assignment, as well as for assignments 7 and 8.
#     * It does not matter if you use a crawler or if you manually collect the links, but you will need at least 100 movie review links. Note that, as of this writing, the robots.txt file of IMDB.com allows the crawling of user reviews.
#     * Each link should be to a web page that has only one user review of only one movie, e.g., the user review permalinks on the IMDB site.
#     * Choose reviews of movies that are all in the same genre, e.g., sci-fi, mystery, romance, superhero, etc.
#     * Make sure your collection includes reviews of several movies in your chosen genre and that it includes a mix of negative and positive reviews.

# %%
from bs4 import BeautifulSoup

# Reference Tutorial: https://www.geeksforgeeks.org/scrape-imdb-movie-rating-and-details-using-python/
# Downloading imdb top 250 movie's data
url = 'http://www.imdb.com/chart/top'
response = requests.get(url)
soup = bs4.BeautifulSoup(response.text, 'lxml')

# Extract movie ratings and details via HTML tags
movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]
votes = [b.attrs.get('data-value') for b in soup.select('td.ratingColumn strong')]

# create a empty list for storing
# movie information
list = []
 
# Iterating over movies to extract
# each movie's details
for index in range(0, len(movies)):
   
    # Separating  movie into: 'place',
    # 'title', 'year'
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    place = movie[:len(str(index))-(len(movie))]
     
    data = {"movie_title": movie_title,
            "year": year,
            "place": place,
            "star_cast": crew[index],
            "rating": ratings[index],
            "vote": votes[index],
            "link": links[index]}
    list.append(data)
    
# printing movie details with its rating.
for movie in list:
    print(movie['place'], '-', movie['movie_title'], '('+movie['year'] +
          ') -', 'Starring:', movie['star_cast'], movie['rating'])
    
movies_df = pd.DataFrame(list)
# Out:
# 1 - The Shawshank Redemption (1994) - Starring: Frank Darabont (dir.), Tim Robbins, Morgan Freeman 9.239894831729572
# 2 - The Godfather (1972) - Starring: Francis Ford Coppola (dir.), Marlon Brando, Al Pacino 9.160892820128788
# 3 - The Dark Knight (2008) - Starring: Christopher Nolan (dir.), Christian Bale, Heath Ledger 8.9928709374644
# 4 - The Godfather: Part II (1974) - Starring: Francis Ford Coppola (dir.), Al Pacino, Robert De Niro 8.99008065987143
# 5 - 12 Angry Men (1957) - Starring: Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb 8.950433269319296
# 6 - Schindler's List (1993) - Starring: Steven Spielberg (dir.), Liam Neeson, Ralph Fiennes 8.939830086357944
# 7 - The Lord of the Rings: The Return of the King (2003) - Starring: Peter Jackson (dir.), Elijah Wood, Viggo Mortensen 8.927082253753648
# 8 - Pulp Fiction (1994) - Starring: Quentin Tarantino (dir.), John Travolta, Uma Thurman 8.859137513598528
# 9 - The Lord of the Rings: The Fellowship of the Ring (2001) - Starring: Peter Jackson (dir.), Elijah Wood, Ian McKellen 8.811311805335123
# 1 -  The Good, the Bad and the Ugly (1966) - Starring: Sergio Leone (dir.), Clint Eastwood, Eli Wallach 8.802560326518403
# 11 - Forrest Gump (1994) - Starring: Robert Zemeckis (dir.), Tom Hanks, Robin Wright 8.776377511478321
# 12 - Fight Club (1999) - Starring: David Fincher (dir.), Brad Pitt, Edward Norton 8.760160814473664
# 13 - Inception (2010) - Starring: Christopher Nolan (dir.), Leonardo DiCaprio, Joseph Gordon-Levitt 8.743816186806066
# 14 - The Lord of the Rings: The Two Towers (2002) - Starring: Peter Jackson (dir.), Elijah Wood, Ian McKellen 8.735404911897156
# 15 - Star Wars: Episode V - The Empire Strikes Back (1980) - Starring: Irvin Kershner (dir.), Mark Hamill, Harrison Ford 8.710011935079235
# 16 - The Matrix (1999) - Starring: Lana Wachowski (dir.), Keanu Reeves, Laurence Fishburne 8.68061692155777
# 17 - Goodfellas (1990) - Starring: Martin Scorsese (dir.), Robert De Niro, Ray Liotta 8.65879385683409
# 18 - One Flew Over the Cuckoo's Nest (1975) - Starring: Milos Forman (dir.), Jack Nicholson, Louise Fletcher 8.649700058753865
# 19 - Se7en (1995) - Starring: David Fincher (dir.), Morgan Freeman, Brad Pitt 8.611722999892086
# 20 - Seven Samurai (1954) - Starring: Akira Kurosawa (dir.), Toshirô Mifune, Takashi Shimura 8.60440352629465
# 21 - It's a Wonderful Life (1946) - Starring: Frank Capra (dir.), James Stewart, Donna Reed 8.603891766054833
# 22 - The Silence of the Lambs (1991) - Starring: Jonathan Demme (dir.), Jodie Foster, Anthony Hopkins 8.596312029278854
# 23 - Saving Private Ryan (1998) - Starring: Steven Spielberg (dir.), Tom Hanks, Matt Damon 8.585560794791393
# 24 - City of God (2002) - Starring: Fernando Meirelles (dir.), Alexandre Rodrigues, Leandro Firmino 8.585157930543453
# 25 - Life Is Beautiful (1997) - Starring: Roberto Benigni (dir.), Roberto Benigni, Nicoletta Braschi 8.572213142479681
# 26 - The Green Mile (1999) - Starring: Frank Darabont (dir.), Tom Hanks, Michael Clarke Duncan 8.567816451332135
# 27 - Star Wars (1977) - Starring: George Lucas (dir.), Mark Hamill, Harrison Ford 8.564862077194716
# 28 - Interstellar (2014) - Starring: Christopher Nolan (dir.), Matthew McConaughey, Anne Hathaway 8.562553035450193
# 29 - Terminator 2: Judgment Day (1991) - Starring: James Cameron (dir.), Arnold Schwarzenegger, Linda Hamilton 8.5445025003402
# 30 - Back to the Future (1985) - Starring: Robert Zemeckis (dir.), Michael J. Fox, Christopher Lloyd 8.52720081465534
# 31 - Spirited Away (2001) - Starring: Hayao Miyazaki (dir.), Daveigh Chase, Suzanne Pleshette 8.523451518323304
# 32 - Psycho (1960) - Starring: Alfred Hitchcock (dir.), Anthony Perkins, Janet Leigh 8.515685295732272
# 33 - Léon: The Professional (1994) - Starring: Luc Besson (dir.), Jean Reno, Gary Oldman 8.512721379845903
# 34 - The Pianist (2002) - Starring: Roman Polanski (dir.), Adrien Brody, Thomas Kretschmann 8.511754301401288
# 35 - Parasite (2019) - Starring: Bong Joon Ho (dir.), Kang-ho Song, Sun-kyun Lee 8.502323221531206
# 36 - The Lion King (1994) - Starring: Roger Allers (dir.), Matthew Broderick, Jeremy Irons 8.49862781442145
# 37 - Gladiator (2000) - Starring: Ridley Scott (dir.), Russell Crowe, Joaquin Phoenix 8.494803852371472
# 38 - American History X (1998) - Starring: Tony Kaye (dir.), Edward Norton, Edward Furlong 8.494099010753107
# 39 - The Usual Suspects (1995) - Starring: Bryan Singer (dir.), Kevin Spacey, Gabriel Byrne 8.486691568008686
# 40 - The Departed (2006) - Starring: Martin Scorsese (dir.), Leonardo DiCaprio, Matt Damon 8.48413088237838
# 41 - Spider-Man: No Way Home (2021) - Starring: Jon Watts (dir.), Tom Holland, Zendaya 8.482792341327468
# 42 - The Prestige (2006) - Starring: Christopher Nolan (dir.), Christian Bale, Hugh Jackman 8.478082949567716
# 43 - Casablanca (1942) - Starring: Michael Curtiz (dir.), Humphrey Bogart, Ingrid Bergman 8.472125896570027
# 44 - Whiplash (2014) - Starring: Damien Chazelle (dir.), Miles Teller, J.K. Simmons 8.46538848517627
# 45 - The Intouchables (2011) - Starring: Olivier Nakache (dir.), François Cluzet, Omar Sy 8.462789315777576
# 46 - Modern Times (1936) - Starring: Charles Chaplin (dir.), Charles Chaplin, Paulette Goddard 8.456790887966633
# 47 - Once Upon a Time in the West (1968) - Starring: Sergio Leone (dir.), Henry Fonda, Charles Bronson 8.455743133559961
# 48 - Hara-Kiri (1962) - Starring: Masaki Kobayashi (dir.), Tatsuya Nakadai, Akira Ishihama 8.452729720105298
# 49 - Grave of the Fireflies (1988) - Starring: Isao Takahata (dir.), Tsutomu Tatsumi, Ayano Shiraishi 8.451930889528379
# 50 - Alien (1979) - Starring: Ridley Scott (dir.), Sigourney Weaver, Tom Skerritt 8.44357821409968
# 51 - Rear Window (1954) - Starring: Alfred Hitchcock (dir.), James Stewart, Grace Kelly 8.443371630353617
# 52 - City Lights (1931) - Starring: Charles Chaplin (dir.), Charles Chaplin, Virginia Cherrill 8.441326408604423
# 53 - Memento (2000) - Starring: Christopher Nolan (dir.), Guy Pearce, Carrie-Anne Moss 8.435637433466995
# 54 - Apocalypse Now (1979) - Starring: Francis Ford Coppola (dir.), Martin Sheen, Marlon Brando 8.432257180523285
# 55 - Cinema Paradiso (1988) - Starring: Giuseppe Tornatore (dir.), Philippe Noiret, Enzo Cannavale 8.431246126208384
# 56 - Indiana Jones and the Raiders of the Lost Ark (1981) - Starring: Steven Spielberg (dir.), Harrison Ford, Karen Allen 8.421528783666991
# 57 - Django Unchained (2012) - Starring: Quentin Tarantino (dir.), Jamie Foxx, Christoph Waltz 8.410821190854247
# 58 - WALL·E (2008) - Starring: Andrew Stanton (dir.), Ben Burtt, Elissa Knight 8.401688203819512
# 59 - The Lives of Others (2006) - Starring: Florian Henckel von Donnersmarck (dir.), Ulrich Mühe, Martina Gedeck 8.391893615957825
# 60 - Sunset Blvd (1950) - Starring: Billy Wilder (dir.), William Holden, Gloria Swanson 8.38870124720243
# 61 - The Shining (1980) - Starring: Stanley Kubrick (dir.), Jack Nicholson, Shelley Duvall 8.376977013518056
# 62 - Paths of Glory (1957) - Starring: Stanley Kubrick (dir.), Kirk Douglas, Ralph Meeker 8.375762102218255
# 63 - The Great Dictator (1940) - Starring: Charles Chaplin (dir.), Charles Chaplin, Paulette Goddard 8.373282790568151
# 64 - Avengers: Infinity War (2018) - Starring: Anthony Russo (dir.), Robert Downey Jr., Chris Hemsworth 8.365442059760225
# 65 - Witness for the Prosecution (1957) - Starring: Billy Wilder (dir.), Tyrone Power, Marlene Dietrich 8.358193537864945
# 66 - Aliens (1986) - Starring: James Cameron (dir.), Sigourney Weaver, Michael Biehn 8.354006846048849
# 67 - The Batman (2022) - Starring: Matt Reeves (dir.), Robert Pattinson, Zoë Kravitz 8.349593784120803
# 68 - American Beauty (1999) - Starring: Sam Mendes (dir.), Kevin Spacey, Annette Bening 8.348000549932621
# 69 - The Dark Knight Rises (2012) - Starring: Christopher Nolan (dir.), Christian Bale, Tom Hardy 8.34586557966094
# 70 - Dr Strangelove or: How I Learned to Stop Worrying and Love the Bomb (1964) - Starring: Stanley Kubrick (dir.), Peter Sellers, George C. Scott 8.340955234840703
# 71 - Joker (2019) - Starring: Todd Phillips (dir.), Joaquin Phoenix, Robert De Niro 8.33619159590399
# 72 - Spider-Man: Into the Spider-Verse (2018) - Starring: Bob Persichetti (dir.), Shameik Moore, Jake Johnson 8.334377610073341
# 73 - Old Boy (2003) - Starring: Park Chan-wook (dir.), Choi Min-sik, Yoo Ji-Tae 8.326479572598972
# 74 - Braveheart (1995) - Starring: Mel Gibson (dir.), Mel Gibson, Sophie Marceau 8.326389210218071
# 75 - Toy Story (1995) - Starring: John Lasseter (dir.), Tom Hanks, Tim Allen 8.32387776057821
# 76 - Amadeus (1984) - Starring: Milos Forman (dir.), F. Murray Abraham, Tom Hulce 8.32135671665579
# 77 - Coco (2017) - Starring: Lee Unkrich (dir.), Anthony Gonzalez, Gael García Bernal 8.320385699719674
# 78 - Inglourious Basterds (2009) - Starring: Quentin Tarantino (dir.), Brad Pitt, Diane Kruger 8.318090032594815
# 79 - The Boat (1981) - Starring: Wolfgang Petersen (dir.), Jürgen Prochnow, Herbert Grönemeyer 8.317345076153662
# 80 - Avengers: Endgame (2019) - Starring: Anthony Russo (dir.), Robert Downey Jr., Chris Evans 8.312539507176385
# 81 - Princess Mononoke (1997) - Starring: Hayao Miyazaki (dir.), Yôji Matsuda, Yuriko Ishida 8.311400108689334
# 82 - Once Upon a Time in America (1984) - Starring: Sergio Leone (dir.), Robert De Niro, James Woods 8.310896828809708
# 83 - Good Will Hunting (1997) - Starring: Gus Van Sant (dir.), Robin Williams, Matt Damon 8.293268775637543
# 84 - Toy Story 3 (2010) - Starring: Lee Unkrich (dir.), Tom Hanks, Tim Allen 8.28927189464279
# 85 - Requiem for a Dream (2000) - Starring: Darren Aronofsky (dir.), Ellen Burstyn, Jared Leto 8.287163328331136
# 86 - 3 Idiots (2009) - Starring: Rajkumar Hirani (dir.), Aamir Khan, Madhavan 8.281213547725024
# 87 - Singin' in the Rain (1952) - Starring: Stanley Donen (dir.), Gene Kelly, Donald O'Connor 8.280314790107601
# 88 - Your Name (2016) - Starring: Makoto Shinkai (dir.), Ryûnosuke Kamiki, Mone Kamishiraishi 8.280137375570513
# 89 - Star Wars: Episode VI - Return of the Jedi (1983) - Starring: Richard Marquand (dir.), Mark Hamill, Harrison Ford 8.278951736697056
# 90 - Reservoir Dogs (1992) - Starring: Quentin Tarantino (dir.), Harvey Keitel, Tim Roth 8.274888285685542
# 91 - Eternal Sunshine of the Spotless Mind (2004) - Starring: Michel Gondry (dir.), Jim Carrey, Kate Winslet 8.274619205200713
# 92 - 2001: A Space Odyssey (1968) - Starring: Stanley Kubrick (dir.), Keir Dullea, Gary Lockwood 8.273696103410433
# 93 - Citizen Kane (1941) - Starring: Orson Welles (dir.), Orson Welles, Joseph Cotten 8.265487500664626
# 94 - High and Low (1963) - Starring: Akira Kurosawa (dir.), Toshirô Mifune, Yutaka Sada 8.264934866045635
# 95 - Lawrence of Arabia (1962) - Starring: David Lean (dir.), Peter O'Toole, Alec Guinness 8.262878015430445
# 96 - M (1931) - Starring: Fritz Lang (dir.), Peter Lorre, Ellen Widmann 8.26137937498796
# 97 - North by Northwest (1959) - Starring: Alfred Hitchcock (dir.), Cary Grant, Eva Marie Saint 8.261112683653632
# 98 - Capernaum (2018) - Starring: Nadine Labaki (dir.), Zain Al Rafeea, Yordanos Shiferaw 8.261111450302977
# 99 - The Hunt (2012) - Starring: Thomas Vinterberg (dir.), Mads Mikkelsen, Thomas Bo Larsen 8.25962569976773
# 10 -  Vertigo (1958) - Starring: Alfred Hitchcock (dir.), James Stewart, Kim Novak 8.254949632320459
# 101 - Amélie (2001) - Starring: Jean-Pierre Jeunet (dir.), Audrey Tautou, Mathieu Kassovitz 8.254640216977167
# 102 - A Clockwork Orange (1971) - Starring: Stanley Kubrick (dir.), Malcolm McDowell, Patrick Magee 8.254344936964655
# 103 - Full Metal Jacket (1987) - Starring: Stanley Kubrick (dir.), Matthew Modine, R. Lee Ermey 8.248405299880865
# 104 - Scarface (1983) - Starring: Brian De Palma (dir.), Al Pacino, Michelle Pfeiffer 8.246206331007919
# 105 - Double Indemnity (1944) - Starring: Billy Wilder (dir.), Fred MacMurray, Barbara Stanwyck 8.243278469741124
# 106 - Come and See (1985) - Starring: Elem Klimov (dir.), Aleksey Kravchenko, Olga Mironova 8.242206140373357
# 107 - The Apartment (1960) - Starring: Billy Wilder (dir.), Jack Lemmon, Shirley MacLaine 8.240863594882192
# 108 - Taxi Driver (1976) - Starring: Martin Scorsese (dir.), Robert De Niro, Jodie Foster 8.23961872376617
# 109 - To Kill a Mockingbird (1962) - Starring: Robert Mulligan (dir.), Gregory Peck, John Megna 8.236347671417748
# 110 - Hamilton (2020) - Starring: Thomas Kail (dir.), Lin-Manuel Miranda, Phillipa Soo 8.235715552942665
# 111 - The Sting (1973) - Starring: George Roy Hill (dir.), Paul Newman, Robert Redford 8.234702451299283
# 112 - LA Confidential (1997) - Starring: Curtis Hanson (dir.), Kevin Spacey, Russell Crowe 8.234512968626085
# 113 - Up (2009) - Starring: Pete Docter (dir.), Edward Asner, Jordan Nagai 8.234369028903787
# 114 - Heat (1995) - Starring: Michael Mann (dir.), Al Pacino, Robert De Niro 8.231990328697755
# 115 - Ikiru (1952) - Starring: Akira Kurosawa (dir.), Takashi Shimura, Nobuo Kaneko 8.230692457780394
# 116 - Snatch (2000) - Starring: Guy Ritchie (dir.), Jason Statham, Brad Pitt 8.23050595097455
# 117 - Die Hard (1988) - Starring: John McTiernan (dir.), Bruce Willis, Alan Rickman 8.230033687656327
# 118 - Indiana Jones and the Last Crusade (1989) - Starring: Steven Spielberg (dir.), Harrison Ford, Sean Connery 8.228276090286574
# 119 - A Separation (2011) - Starring: Asghar Farhadi (dir.), Payman Maadi, Leila Hatami 8.22789448677352
# 120 - Metropolis (1927) - Starring: Fritz Lang (dir.), Brigitte Helm, Alfred Abel 8.226975639578
# 121 - Bicycle Thieves (1948) - Starring: Vittorio De Sica (dir.), Lamberto Maggiorani, Enzo Staiola 8.22325473282756
# 122 - Incendies (2010) - Starring: Denis Villeneuve (dir.), Lubna Azabal, Mélissa Désormeaux-Poulin 8.222753016526815
# 123 - 1917 (2019) - Starring: Sam Mendes (dir.), Dean-Charles Chapman, George MacKay 8.219989758706623
# 124 - Like Stars on Earth (2007) - Starring: Aamir Khan (dir.), Darsheel Safary, Aamir Khan 8.21888893082783
# 125 - Batman Begins (2005) - Starring: Christopher Nolan (dir.), Christian Bale, Michael Caine 8.217596512059046
# 126 - For a Few Dollars More (1965) - Starring: Sergio Leone (dir.), Clint Eastwood, Lee Van Cleef 8.212335992453244
# 127 - Dangal (2016) - Starring: Nitesh Tiwari (dir.), Aamir Khan, Sakshi Tanwar 8.21167176559434
# 128 - Downfall (2004) - Starring: Oliver Hirschbiegel (dir.), Bruno Ganz, Alexandra Maria Lara 8.210913899006115
# 129 - The Kid (1921) - Starring: Charles Chaplin (dir.), Charles Chaplin, Edna Purviance 8.201881701065588
# 130 - Some Like It Hot (1959) - Starring: Billy Wilder (dir.), Marilyn Monroe, Tony Curtis 8.197803888472546
# 131 - The Father (2020) - Starring: Florian Zeller (dir.), Anthony Hopkins, Olivia Colman 8.190777675362217
# 132 - All About Eve (1950) - Starring: Joseph L. Mankiewicz (dir.), Bette Davis, Anne Baxter 8.184869666101505
# 133 - Green Book (2018) - Starring: Peter Farrelly (dir.), Viggo Mortensen, Mahershala Ali 8.180977847584947
# 134 - The Wolf of Wall Street (2013) - Starring: Martin Scorsese (dir.), Leonardo DiCaprio, Jonah Hill 8.180401396603811
# 135 - Unforgiven (1992) - Starring: Clint Eastwood (dir.), Clint Eastwood, Gene Hackman 8.173022243091701
# 136 - Casino (1995) - Starring: Martin Scorsese (dir.), Robert De Niro, Sharon Stone 8.172616308951884
# 137 - Pan's Labyrinth (2006) - Starring: Guillermo del Toro (dir.), Ivana Baquero, Ariadna Gil 8.172260433757861
# 138 - Judgment at Nuremberg (1961) - Starring: Stanley Kramer (dir.), Spencer Tracy, Burt Lancaster 8.172110823494078
# 139 - Ran (1985) - Starring: Akira Kurosawa (dir.), Tatsuya Nakadai, Akira Terao 8.166975613208528
# 140 - A Beautiful Mind (2001) - Starring: Ron Howard (dir.), Russell Crowe, Ed Harris 8.163380465903211
# 141 - The Sixth Sense (1999) - Starring: M. Night Shyamalan (dir.), Bruce Willis, Haley Joel Osment 8.161435434407164
# 142 - Monty Python and the Holy Grail (1975) - Starring: Terry Gilliam (dir.), Graham Chapman, John Cleese 8.161121667254879
# 143 - There Will Be Blood (2007) - Starring: Paul Thomas Anderson (dir.), Daniel Day-Lewis, Paul Dano 8.159313426534384
# 144 - The Truman Show (1998) - Starring: Peter Weir (dir.), Jim Carrey, Ed Harris 8.156800148598931
# 145 - Yojimbo (1961) - Starring: Akira Kurosawa (dir.), Toshirô Mifune, Eijirô Tôno 8.154633194807204
# 146 - The Treasure of the Sierra Madre (1948) - Starring: John Huston (dir.), Humphrey Bogart, Walter Huston 8.152964050515337
# 147 - Shutter Island (2010) - Starring: Martin Scorsese (dir.), Leonardo DiCaprio, Emily Mortimer 8.150888775703464
# 148 - The Great Escape (1963) - Starring: John Sturges (dir.), Steve McQueen, James Garner 8.150142253530523
# 149 - Rashomon (1950) - Starring: Akira Kurosawa (dir.), Toshirô Mifune, Machiko Kyô 8.148697566939278
# 150 - Jurassic Park (1993) - Starring: Steven Spielberg (dir.), Sam Neill, Laura Dern 8.145350376403691
# 151 - Kill Bill: Vol 1 (2003) - Starring: Quentin Tarantino (dir.), Uma Thurman, David Carradine 8.14461851808856
# 152 - Finding Nemo (2003) - Starring: Andrew Stanton (dir.), Albert Brooks, Ellen DeGeneres 8.141702674137154
# 153 - No Country for Old Men (2007) - Starring: Ethan Coen (dir.), Tommy Lee Jones, Javier Bardem 8.141453622579267
# 154 - Raging Bull (1980) - Starring: Martin Scorsese (dir.), Robert De Niro, Cathy Moriarty 8.139929200079486
# 155 - The Elephant Man (1980) - Starring: David Lynch (dir.), Anthony Hopkins, John Hurt 8.138646473434832
# 156 - V for Vendetta (2005) - Starring: James McTeigue (dir.), Hugo Weaving, Natalie Portman 8.138532613920294
# 157 - Gone with the Wind (1939) - Starring: Victor Fleming (dir.), Clark Gable, Vivien Leigh 8.137563868083367
# 158 - Chinatown (1974) - Starring: Roman Polanski (dir.), Jack Nicholson, Faye Dunaway 8.1357169268925
# 159 - Inside Out (2015) - Starring: Pete Docter (dir.), Amy Poehler, Bill Hader 8.134621764318203
# 160 - Lock, Stock and Two Smoking Barrels (1998) - Starring: Guy Ritchie (dir.), Jason Flemyng, Dexter Fletcher 8.132463353597757
# 161 - The Thing (1982) - Starring: John Carpenter (dir.), Kurt Russell, Wilford Brimley 8.130793624879681
# 162 - Dial M for Murder (1954) - Starring: Alfred Hitchcock (dir.), Ray Milland, Grace Kelly 8.124834857047956
# 163 - The Secret in Their Eyes (2009) - Starring: Juan José Campanella (dir.), Ricardo Darín, Soledad Villamil 8.123988166199737
# 164 - Howl's Moving Castle (2004) - Starring: Hayao Miyazaki (dir.), Chieko Baishô, Takuya Kimura 8.123328665461095
# 165 - The Bridge on the River Kwai (1957) - Starring: David Lean (dir.), William Holden, Alec Guinness 8.121515996613894
# 166 - Trainspotting (1996) - Starring: Danny Boyle (dir.), Ewan McGregor, Ewen Bremner 8.118959919899071
# 167 - Three Billboards Outside Ebbing, Missouri (2017) - Starring: Martin McDonagh (dir.), Frances McDormand, Woody Harrelson 8.117653647179138
# 168 - Warrior (2011) - Starring: Gavin O'Connor (dir.), Tom Hardy, Nick Nolte 8.117551058439417
# 169 - Gran Torino (2008) - Starring: Clint Eastwood (dir.), Clint Eastwood, Bee Vang 8.115359799208349
# 170 - Fargo (1996) - Starring: Joel Coen (dir.), William H. Macy, Frances McDormand 8.109947317910768
# 171 - My Neighbor Totoro (1988) - Starring: Hayao Miyazaki (dir.), Hitoshi Takagi, Noriko Hidaka 8.104831974463108
# 172 - Prisoners (2013) - Starring: Denis Villeneuve (dir.), Hugh Jackman, Jake Gyllenhaal 8.099658966504427
# 173 - Million Dollar Baby (2004) - Starring: Clint Eastwood (dir.), Hilary Swank, Clint Eastwood 8.098092014948609
# 174 - Blade Runner (1982) - Starring: Ridley Scott (dir.), Harrison Ford, Rutger Hauer 8.09509814308869
# 175 - The Gold Rush (1925) - Starring: Charles Chaplin (dir.), Charles Chaplin, Mack Swain 8.09458225094434
# 176 - Catch Me If You Can (2002) - Starring: Steven Spielberg (dir.), Leonardo DiCaprio, Tom Hanks 8.094149639649096
# 177 - On the Waterfront (1954) - Starring: Elia Kazan (dir.), Marlon Brando, Karl Malden 8.093464195000355
# 178 - Children of Heaven (1997) - Starring: Majid Majidi (dir.), Mohammad Amir Naji, Amir Farrokh Hashemian 8.09064322874535
# 179 - Harry Potter and the Deathly Hallows: Part 2 (2011) - Starring: David Yates (dir.), Daniel Radcliffe, Emma Watson 8.089545099416762
# 180 - The Third Man (1949) - Starring: Carol Reed (dir.), Orson Welles, Joseph Cotten 8.089375285669325
# 181 - Gone Girl (2014) - Starring: David Fincher (dir.), Ben Affleck, Rosamund Pike 8.086293839922782
# 182 - Ben-Hur (1959) - Starring: William Wyler (dir.), Charlton Heston, Jack Hawkins 8.08558050133001
# 183 - 12 Years a Slave (2013) - Starring: Steve McQueen (dir.), Chiwetel Ejiofor, Michael Kenneth Williams 8.085385525562707
# 184 - The General (1926) - Starring: Clyde Bruckman (dir.), Buster Keaton, Marion Mack 8.084184965674405
# 185 - The Deer Hunter (1978) - Starring: Michael Cimino (dir.), Robert De Niro, Christopher Walken 8.08368774326788
# 186 - Wild Strawberries (1957) - Starring: Ingmar Bergman (dir.), Victor Sjöström, Bibi Andersson 8.081708462041494
# 187 - Before Sunrise (1995) - Starring: Richard Linklater (dir.), Ethan Hawke, Julie Delpy 8.081100648799222
# 188 - In the Name of the Father (1993) - Starring: Jim Sheridan (dir.), Daniel Day-Lewis, Pete Postlethwaite 8.080530842964603
# 189 - Pather Panchali (1955) - Starring: Satyajit Ray (dir.), Kanu Bannerjee, Karuna Bannerjee 8.080236103390087
# 190 - Mr Smith Goes to Washington (1939) - Starring: Frank Capra (dir.), James Stewart, Jean Arthur 8.07839270734995
# 191 - The Grand Budapest Hotel (2014) - Starring: Wes Anderson (dir.), Ralph Fiennes, F. Murray Abraham 8.077984840599145
# 192 - Room (2015) - Starring: Lenny Abrahamson (dir.), Brie Larson, Jacob Tremblay 8.077683503186439
# 193 - Sherlock Jr (1924) - Starring: Buster Keaton (dir.), Buster Keaton, Kathryn McGuire 8.075628119800127
# 194 - Hacksaw Ridge (2016) - Starring: Mel Gibson (dir.), Andrew Garfield, Sam Worthington 8.075389166915924
# 195 - How to Train Your Dragon (2010) - Starring: Dean DeBlois (dir.), Jay Baruchel, Gerard Butler 8.074721858160734
# 196 - The Wages of Fear (1953) - Starring: Henri-Georges Clouzot (dir.), Yves Montand, Charles Vanel 8.074423265563606
# 197 - Memories of Murder (2003) - Starring: Bong Joon Ho (dir.), Kang-ho Song, Kim Sang-kyung 8.074223800539643
# 198 - The Seventh Seal (1957) - Starring: Ingmar Bergman (dir.), Max von Sydow, Gunnar Björnstrand 8.073443594944832
# 199 - Barry Lyndon (1975) - Starring: Stanley Kubrick (dir.), Ryan O'Neal, Marisa Berenson 8.073023926007616
# 200 - The Big Lebowski (1998) - Starring: Joel Coen (dir.), Jeff Bridges, John Goodman 8.071898745056549
# 201 - Klaus (2019) - Starring: Sergio Pablos (dir.), Jason Schwartzman, J.K. Simmons 8.07173613617997
# 202 - Mad Max: Fury Road (2015) - Starring: George Miller (dir.), Tom Hardy, Charlize Theron 8.071630176642524
# 203 - Wild Tales (2014) - Starring: Damián Szifron (dir.), Darío Grandinetti, María Marull 8.070423727213383
# 204 - Monsters, Inc (2001) - Starring: Pete Docter (dir.), Billy Crystal, John Goodman 8.06809532549372
# 205 - Mary and Max (2009) - Starring: Adam Elliot (dir.), Toni Collette, Philip Seymour Hoffman 8.066201444298708
# 206 - Jaws (1975) - Starring: Steven Spielberg (dir.), Roy Scheider, Robert Shaw 8.066009069005124
# 207 - The Passion of Joan of Arc (1928) - Starring: Carl Theodor Dreyer (dir.), Maria Falconetti, Eugene Silvain 8.063256185098778
# 208 - Hotel Rwanda (2004) - Starring: Terry George (dir.), Don Cheadle, Sophie Okonedo 8.061155067191004
# 209 - Rocky (1976) - Starring: John G. Avildsen (dir.), Sylvester Stallone, Talia Shire 8.05853449094344
# 210 - Dead Poets Society (1989) - Starring: Peter Weir (dir.), Robin Williams, Robert Sean Leonard 8.057319755523146
# 211 - Tokyo Story (1953) - Starring: Yasujirô Ozu (dir.), Chishû Ryû, Chieko Higashiyama 8.05699523868798
# 212 - Platoon (1986) - Starring: Oliver Stone (dir.), Charlie Sheen, Tom Berenger 8.055534472800815
# 213 - The Terminator (1984) - Starring: James Cameron (dir.), Arnold Schwarzenegger, Linda Hamilton 8.052488711394625
# 214 - Ford v Ferrari (2019) - Starring: James Mangold (dir.), Matt Damon, Christian Bale 8.052441120268186
# 215 - Stand by Me (1986) - Starring: Rob Reiner (dir.), Wil Wheaton, River Phoenix 8.051883205969926
# 216 - Rush (2013) - Starring: Ron Howard (dir.), Daniel Brühl, Chris Hemsworth 8.049535128690522
# 217 - Into the Wild (2007) - Starring: Sean Penn (dir.), Emile Hirsch, Vince Vaughn 8.048649335251596
# 218 - The Wizard of Oz (1939) - Starring: Victor Fleming (dir.), Judy Garland, Frank Morgan 8.046957497925211
# 219 - Logan (2017) - Starring: James Mangold (dir.), Hugh Jackman, Patrick Stewart 8.046416913156355
# 220 - Spotlight (2015) - Starring: Tom McCarthy (dir.), Mark Ruffalo, Michael Keaton 8.044962270582593
# 221 - Network (1976) - Starring: Sidney Lumet (dir.), Faye Dunaway, William Holden 8.043227898214438
# 222 - Groundhog Day (1993) - Starring: Harold Ramis (dir.), Bill Murray, Andie MacDowell 8.041847086489103
# 223 - The Exorcist (1973) - Starring: William Friedkin (dir.), Ellen Burstyn, Max von Sydow 8.038445631961077
# 224 - Ratatouille (2007) - Starring: Brad Bird (dir.), Brad Garrett, Lou Romano 8.038233434358693
# 225 - Hachi: A Dog's Tale (2009) - Starring: Lasse Hallström (dir.), Richard Gere, Joan Allen 8.03535432524593
# 226 - The Incredibles (2004) - Starring: Brad Bird (dir.), Craig T. Nelson, Samuel L. Jackson 8.034789062272711
# 227 - Dersu Uzala (1975) - Starring: Akira Kurosawa (dir.), Maksim Munzuk, Yuriy Solomin 8.034490172839053
# 228 - The Best Years of Our Lives (1946) - Starring: William Wyler (dir.), Myrna Loy, Dana Andrews 8.033381327361015
# 229 - Before Sunset (2004) - Starring: Richard Linklater (dir.), Ethan Hawke, Julie Delpy 8.032714393552139
# 230 - Rebecca (1940) - Starring: Alfred Hitchcock (dir.), Laurence Olivier, Joan Fontaine 8.030839114313556
# 231 - Dune (2021) - Starring: Denis Villeneuve (dir.), Timothée Chalamet, Rebecca Ferguson 8.03056850887433
# 232 - The Grapes of Wrath (1940) - Starring: John Ford (dir.), Henry Fonda, Jane Darwell 8.029507725673403
# 233 - My Father and My Son (2005) - Starring: Cagan Irmak (dir.), Eser Sariyar, Çetin Tekindor 8.029430777211497
# 234 - Cool Hand Luke (1967) - Starring: Stuart Rosenberg (dir.), Paul Newman, George Kennedy 8.028972729014274
# 235 - To Be or Not to Be (1942) - Starring: Ernst Lubitsch (dir.), Carole Lombard, Jack Benny 8.028169674264438
# 236 - Amores perros (2000) - Starring: Alejandro G. Iñárritu (dir.), Emilio Echevarría, Gael García Bernal 8.027410507863701
# 237 - The Battle of Algiers (1966) - Starring: Gillo Pontecorvo (dir.), Brahim Hadjadj, Jean Martin 8.027379793726562
# 238 - Pirates of the Caribbean: The Curse of the Black Pearl (2003) - Starring: Gore Verbinski (dir.), Johnny Depp, Geoffrey Rush 8.027298472039227
# 239 - The Sound of Music (1965) - Starring: Robert Wise (dir.), Julie Andrews, Christopher Plummer 8.023241230116689
# 240 - Life of Brian (1979) - Starring: Terry Jones (dir.), Graham Chapman, John Cleese 8.022329083194592
# 241 - The 400 Blows (1959) - Starring: François Truffaut (dir.), Jean-Pierre Léaud, Albert Rémy 8.021936579261714
# 242 - Persona (1966) - Starring: Ingmar Bergman (dir.), Bibi Andersson, Liv Ullmann 8.021465615876016
# 243 - It Happened One Night (1934) - Starring: Frank Capra (dir.), Clark Gable, Claudette Colbert 8.02037384891987
# 244 - La Haine (1995) - Starring: Mathieu Kassovitz (dir.), Vincent Cassel, Hubert Koundé 8.019496552797236
# 245 - Aladdin (1992) - Starring: Ron Clements (dir.), Scott Weinger, Robin Williams 8.018554930865921
# 246 - Beauty and the Beast (1991) - Starring: Gary Trousdale (dir.), Paige O'Hara, Robby Benson 8.01722578169394
# 247 - Gandhi (1982) - Starring: Richard Attenborough (dir.), Ben Kingsley, John Gielgud 8.015661167481062
# 248 - Jai Bhim (2021) - Starring: T.J. Gnanavel (dir.), Suriya, Lijo Mol Jose 8.01533585326333
# 249 - The Help (2011) - Starring: Tate Taylor (dir.), Emma Stone, Viola Davis 8.014695313450401
# 250 - The Handmaiden (2016) - Starring: Park Chan-wook (dir.), Kim Min-hee, Ha Jung-woo 8.0126537506892

# %%
movies_df.to_csv("top_250_movies.csv")

# %%
movies_df.head()
# Out:
#                 movie_title  year place  \
# 0  The Shawshank Redemption  1994     1
# 1             The Godfather  1972     2
# 2           The Dark Knight  2008     3
# 3    The Godfather: Part II  1974     4
# 4              12 Angry Men  1957     5
#
#                                            star_cast             rating  vote  \
# 0  Frank Darabont (dir.), Tim Robbins, Morgan Fre...  9.239894831729572  None
# 1  Francis Ford Coppola (dir.), Marlon Brando, Al...  9.160892820128788  None
# 2  Christopher Nolan (dir.), Christian Bale, Heat...    8.9928709374644  None
# 3  Francis Ford Coppola (dir.), Al Pacino, Robert...   8.99008065987143  None
# 4      Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb  8.950433269319296  None
#
#                 link
# 0  /title/tt0111161/
# 1  /title/tt0068646/
# 2  /title/tt0468569/
# 3  /title/tt0071562/
# 4  /title/tt0050083/

# %% [markdown]
# 2.	Extract noun phrase (NP) chunks from your reviews using the following procedure:
#     * In Python, use BeautifulSoup to grab the main review text from each link.
#     * Next run each review text through a tokenizer, and then try to NP-chunk it with a shallow parser.
#     * You probably will have too many unknown words, owing to proper names of characters, actors, and so on that are not in your working dictionary. Make sure the main names that are relevant to the movies in your collection of reviews are added to the working lexicon, and then run the NP chunker again.

# %%
def get_review_headliner(title_url_link):
    """Retrieves review headliner text for top 25 reviews displayed for a given movie title"""
    url = f"https://www.imdb.com{title_url_link}reviews"  # review link pattern for imdb
    response = requests.get(url)  # hit the original page
    soup = bs4.BeautifulSoup(response.text, 'html.parser')
    #list comphrehension for imdb movie reviews for specific title
    #remove leading whitespace and ending \n because IMDB formats it that way
    return [headline.get_text().lstrip().strip('\n') for headline in soup.find_all('a', class_='title',href=True)] 

shawshank_reviews = get_review_headliner(movies_df["link"].iloc[0])
godfather_reviews = get_review_headliner(movies_df["link"].iloc[1])
dark_knight_reviews = get_review_headliner(movies_df["link"].iloc[2])
godfather_II_reviews = get_review_headliner(movies_df["link"].iloc[3])

print(f"""Webscrapped {len(shawshank_reviews) + len(godfather_reviews) + len(dark_knight_reviews) + len(godfather_II_reviews)} reviews from top 4 movies:
({movies_df.head(4)['movie_title']})""")
# Out:
# Webscrapped 100 reviews from top 4 movies:
# (0    The Shawshank Redemption
# 1               The Godfather
# 2             The Dark Knight
# 3      The Godfather: Part II
# Name: movie_title, dtype: object)

# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# %%
# Ch. 7.2.3 of nltk.org book
grammar = r"""
  NP: {<DT|PP\$>?<JJ>*<NN>}   # chunk determiner/possessive, adjectives and noun
      {<NNP>+}                # chunk sequences of proper nouns
"""

cp = nltk.RegexpParser(grammar)


def shallow_np_chunk_parse(review_headliners):
  """ given a list of review headliners, tokenize, filter, tag, chunk, and then parse for noun-phrases. Prints out subtrees of noun phrases and returns list of them
  """
  noun_phrases = []
  
  for review in review_headliners:
      review_tokens = nltk.word_tokenize(review)  # tokenize inputted sentences
      filtered_review_tokens = [token for token in review_tokens if not token.lower() in set(stopwords.words('english'))]  # remove common english stopwords
      tagged_tokens = nltk.pos_tag(filtered_review_tokens)  # Tag each token as a part of speech
      chunks = nltk.chunk.ne_chunk(tagged_tokens)  # Create chunks using recommended named entity chunker for the pos tagged tokens
      result = cp.parse(chunks)  # Use the Regexp Parser and custom grammar rules to parse each chunk for the noun phrase subtrees
      for subtree in result.subtrees(filter=lambda t: t.label() == 'NP'): # use lambda to filter subtrees on NP
        noun_phrases.append(subtree)
  
  return noun_phrases

# %%
noun_phrases = shallow_np_chunk_parse(shawshank_reviews)
noun_phrases.append(shallow_np_chunk_parse(godfather_reviews))
noun_phrases.append(shallow_np_chunk_parse(dark_knight_reviews))
noun_phrases.append(shallow_np_chunk_parse(godfather_II_reviews))

# %% [markdown]
# 3.	Output all the chunks in a single list for each review, and submit that output for this assignment. Also submit a brief written summary of what you did (describe your selection of genre, your source of reviews, how many you collected, and by what means).

# %%
from pprint import pprint
pprint(noun_phrases)
# Out:
# [Tree('NP', [('All-time', 'JJ'), ('prison', 'NN')]),
#  Tree('NP', [('film', 'NN')]),
#  Tree('NP', [('depth', 'NN')]),
#  Tree('NP', [('great', 'JJ'), ('story', 'NN')]),
#  Tree('NP', [('incredible', 'JJ'), ('movie', 'NN')]),
#  Tree('NP', [('convicted', 'JJ'), ('murderer', 'NN')]),
#  Tree('NP', [('sound', 'JJ'), ('financial', 'JJ'), ('planning', 'NN')]),
#  Tree('NP', [('hope', 'NN')]),
#  Tree('NP', [('Time', 'NNP')]),
#  Tree('NP', [('Time', 'NNP'), ('Pressure', 'NNP')]),
#  Tree('NP', [('extraordinary', 'JJ'), ('unforgettable', 'JJ'), ('film', 'NN')]),
#  Tree('NP', [('bank', 'NN')]),
#  Tree('NP', [('veep', 'NN')]),
#  Tree('NP', [('prison', 'NN')]),
#  Tree('NP', [('genre', 'JJ'), ('picture', 'NN')]),
#  Tree('NP', [('Redemption-', 'NNP')]),
#  Tree('NP', [('*', 'NNP'), ('*', 'NNP'), ('*', 'NNP')]),
#  Tree('NP', [('*', 'NN')]),
#  Tree('NP', [('Redemption', 'NNP')]),
#  Tree('NP', [('Relentless', 'NNP')]),
#  Tree('NP', [('movie', 'NN')]),
#  Tree('NP', [('masterpiece', 'NN')]),
#  [Tree('NP', [('multi-Oscar-winner', 'NN')]),
#   Tree('NP', [('reviews', 'NN')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('hard', 'JJ'), ('describe', 'NN')]),
#   Tree('NP', [('amazing', 'JJ'), ('movie', 'NN')]),
#   Tree('NP', [('Everything', 'NN')]),
#   Tree('NP', [('Godfather', 'NNP')]),
#   Tree('NP', [('Perfection', 'NNP')]),
#   Tree('NP', [('unique', 'NN')]),
#   Tree('NP', [('Godfather', 'NN')]),
#   Tree('NP', [('family', 'NN')]),
#   Tree('NP', [('crime', 'NN')]),
#   Tree('NP', [('time', 'NN')]),
#   Tree('NP', [('justice', 'NN')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('Godfather', 'NN')]),
#   Tree('NP', [('Excellent', 'JJ'), ('Execution', 'NN')]),
#   Tree('NP', [('See', 'NNP')]),
#   Tree('NP', [('sprawling', 'NN')]),
#   Tree('NP', [('epic', 'NN')]),
#   Tree('NP', [('Mafia', 'NNP')]),
#   Tree('NP', [('masterpiece', 'NN')]),
#   Tree('NP', [('sure', 'JJ'), ('give', 'JJ'), ('respect', 'NN')]),
#   Tree('NP', [('adaptation', 'NN')]),
#   Tree('NP', [('cornerstone', 'NN')]),
#   Tree('NP', [('cinema', 'NN')]),
#   Tree('NP', [('number', 'NN')]),
#   Tree('NP', [('obvious', 'JJ'), ('word', 'NN')]),
#   Tree('NP', [('masterpiece', 'NN')]),
#   Tree('NP', [('Godfather', 'NNP')]),
#   Tree('NP', [('compelling', 'NN')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('watch', 'NN')]),
#   Tree('NP', [('time', 'NN')])],
#  [Tree('NP', [('non-stop', 'JJ'), ('action', 'NN')]),
#   Tree('NP', [('eye-popping', 'JJ'), ('skyscraper', 'NN')]),
#   Tree('NP', [('moody', 'NN')]),
#   Tree('NP', [('Heath', 'NNP'), ('Ledger', 'NNP')]),
#   Tree('NP', [('bleak', 'NN')]),
#   Tree('NP', [('Knight', 'NNP')]),
#   Tree('NP', [('Impressive', 'JJ'), ('blockbuster', 'NN')]),
#   Tree('NP', [('dark', 'NN')]),
#   Tree('NP', [('tone', 'NN')]),
#   Tree('NP', [('plot', 'NN')]),
#   Tree('NP', [('delivery', 'NN')]),
#   Tree('NP', [('making', 'NN')]),
#   Tree('NP', [('version', 'NN')]),
#   Tree('NP', [('think', 'NN')]),
#   Tree('NP', [('morality', 'NN')]),
#   Tree('NP', [('Knight', 'NNP')]),
#   Tree('NP', [('Big-Time', 'NNP')]),
#   Tree('NP', [('hype', 'NN')]),
#   Tree('NP', [('action', 'NN')]),
#   Tree('NP', [('production', 'NN')]),
#   Tree('NP', [('design', 'NN')]),
#   Tree('NP', [('crusader', 'NN')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('word', 'NN')]),
#   Tree('NP', [('terrorist', 'NN')]),
#   Tree('NP', [('plot', 'NN')]),
#   Tree('NP', [('park', 'NN')]),
#   Tree('NP', [('Knight', 'NNP')]),
#   Tree('NP', [('Batman', 'NNP')]),
#   Tree('NP', [('movie', 'NN')]),
#   Tree('NP', [('Knight-Joker', 'NNP'), ('Others', 'NNP'), ('Go', 'NNP')]),
#   Tree('NP', [('*', 'NNP'), ('*', 'NNP')]),
#   Tree('NP', [('*', 'NN')])],
#  [Tree('NP', [('review', 'NN')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('masterpiece', 'NN')]),
#   Tree('NP', [('rich', 'JJ'), ('epic', 'NN')]),
#   Tree('NP', [('great', 'JJ'), ('tale', 'JJ'), ('corrupting', 'NN')]),
#   Tree('NP', [('nature', 'NN')]),
#   Tree('NP', [('power', 'NN')]),
#   Tree('NP', [('forth', 'NN')]),
#   Tree('NP', [('equal', 'JJ'), ('sequel', 'NN')]),
#   Tree('NP', [('First', 'NNP')]),
#   Tree('NP', [('II', 'NNP')]),
#   Tree('NP', [('Excellent', 'JJ'), ('dramatic', 'JJ'), ('story', 'NN')]),
#   Tree('NP', [("It's-a", 'JJ'), ('good', 'NN')]),
#   Tree('NP', [('Godfather', 'NN')]),
#   Tree('NP', [('predecessor', 'NN')]),
#   Tree('NP', [('II', 'NNP')]),
#   Tree('NP', [('Godfather', 'NNP')]),
#   Tree('NP', [('film', 'NN')]),
#   Tree('NP', [('First', 'NNP')]),
#   Tree('NP', [('anything', 'NN')]),
#   Tree('NP', [('life', 'NN')]),
#   Tree('NP', [('history', 'NN')]),
#   Tree('NP', [('anything', 'NN')]),
#   Tree('NP', [('anyone', 'NN')])]]
